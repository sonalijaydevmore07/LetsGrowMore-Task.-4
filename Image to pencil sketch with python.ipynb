# %% [markdown]
# # LetsGrowMore : Data Science Internship

# %% [markdown]
# # Task 4: Image to pencil sketch with Python

# %% [markdown]
# # Intern Name : Sonali Vilas Khude

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\sonali jaydev more\appdata\roaming\python\python39\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import libraries

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# Loading original image

# %%
image = cv2.imread("C:/Users/Sonali Jaydev More/Downloads/shivaji-maharaj-pvc-card-02.jpg")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# Converting image to grey scale

# %%
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,10))
plt.imshow(image_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
#  invert the new grayscale image

# %%
image_invert = cv2.bitwise_not(image_gray)
plt.figure(figsize=(10,10))
plt.imshow(image_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %%
image_smoothing = cv2.GaussianBlur(image_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(10,10))
plt.imshow(image_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothened Image")
plt.show()

# %% [markdown]
# Converting image to pencil sketch

# %%
sketch = cv2.divide(image_gray,255-image_smoothing, scale=255)
plt.figure(figsize=(10,10))
plt.imshow(sketch,cmap="gray")
plt.axis("off")
plt.title("Pencilsketch Image")
plt.show()

# %% [markdown]
# # Thank You.
